# %%
import jieba
from os import path
from imageio import imread          #imread 读取图像
import pandas as pd
import matplotlib.pyplot as plt      #可视化
import os
os.chdir("C:/Users/Starrism.Jia/Documents/python daima/cipinciyun/word_cloud-master/examples")
from wordcloud import WordCloud, ImageColorGenerator
 
# get data directory (using getcwd() is needed to support running example in generated IPython notebook)
d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()
 
# Chinese fonts must be set
font_path ='C:/Windows/Fonts/simhei.ttf'
 
def makeImage(text):
    back_coloring = imread(path.join(d, d + '/wc_cn/gift2.jpg'))                           #读取背景图片
 
    wc = WordCloud(font_path=font_path,background_color="white", max_words=1000, mask=back_coloring)
    # generate word cloud
    wc.generate_from_frequencies(text)                                                   #根据我的词频文件                   
    wc.to_file(path.join(d, d+'/wc_cn/gift.png'))                                       #生成词云并保存图像
     
    # show
    plt.imshow(wc, interpolation="bilinear")      #输出栏展示图像
    plt.axis("off")
    plt.show()
     
     
 
#输入文本文件 
word_freq2 = pd.read_excel("C:/Users/Starrism.Jia/Documents/python daima/cipinciyun/word_freq.xlsx")
word = word_freq.word  # 词
value = word_freq.freq  # 词的频率
dic = dict(zip(word, value))     #构建词频字典
makeImage(dic)
# Out:
# C:\Users\Starrism.Jia\AppData\Local\Temp\ipykernel_6636\841295166.py:17: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   back_coloring = imread(path.join(d, d + '/wc_cn/gift2.jpg'))
# C:\Users\Starrism.Jia\AppData\Local\Temp\ipykernel_6636\841295166.py:22: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   back_coloring = imread(path.join(d, d + '/wc_cn/gift2.jpg'))
